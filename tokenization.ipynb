# %%
# %pip install tiktoken
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tiktoken


enc=tiktoken.encoding_for_model("gpt-4o")

# %%
text="Hey My name is Aditya Rao"
enc.encode(text)
# Out:
# [25216, 3673, 1308, 382, 2686, 128947, 171935]

# %%
enc.decode([25216, 3673, 1308, 382, 2686, 128947, 171935])
# Out:
# 'Hey My name is Aditya Rao'

# %%
text2="How are you"
enc.encode(text2)
# Out:
# [5299, 553, 481]

# %%
enc.decode([5299, 553, 481])
# Out:
# 'How are you'
