# %% [markdown]
# Term Frequency And Inverse Document Frequency

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documents = [
    "I love learning Machine Learning!",
    "I am studying NLP and Machine Learning.",
    "NLP is interesting and powerful!"
]

# %%
#create object
vectorizor=TfidfVectorizer()

# %%
x=vectorizor.fit_transform(documents)

# %%
x
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 14 stored elements and shape (3, 10)>

# %%
print(vectorizor.get_feature_names_out())
# Out:
# ['am' 'and' 'interesting' 'is' 'learning' 'love' 'machine' 'nlp'
#  'powerful' 'studying']

# %%
#TDF matrix
print(x.toarray())
# Out:
# [[0.         0.         0.         0.         0.77100584 0.50689001
#   0.38550292 0.         0.         0.        ]
#  [0.48148213 0.36617957 0.         0.         0.36617957 0.
#   0.36617957 0.36617957 0.         0.48148213]
#  [0.         0.37302199 0.49047908 0.49047908 0.         0.
#   0.         0.37302199 0.49047908 0.        ]]
