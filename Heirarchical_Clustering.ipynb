# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram,linkage

# %%
df=pd.DataFrame({
    "Age":[20,22,25,45,48,50],
    "Spending":[2000,2500,3000,18000,20000,22000]
})

print(df)
# Out:
#    Age  Spending
# 0   20      2000
# 1   22      2500
# 2   25      3000
# 3   45     18000
# 4   48     20000
# 5   50     22000

# %%
scaler=StandardScaler()
scaled_data=scaler.fit_transform(df)

# %%
#dendogram
linked=linkage(scaled_data,method="ward")
dendrogram(linked)
# Out:
# {'icoord': [[15.0, 15.0, 25.0, 25.0],
#   [5.0, 5.0, 20.0, 20.0],
#   [45.0, 45.0, 55.0, 55.0],
#   [35.0, 35.0, 50.0, 50.0],
#   [12.5, 12.5, 42.5, 42.5]],
#  'dcoord': [[0.0,
#    np.float64(0.16582364873598915),
#    np.float64(0.16582364873598915),
#    0.0],
#   [0.0,
#    np.float64(0.37305845303875634),
#    np.float64(0.37305845303875634),
#    np.float64(0.16582364873598915)],
#   [0.0, np.float64(0.2749313551529547), np.float64(0.2749313551529547), 0.0],
#   [0.0,
#    np.float64(0.5323926296278343),
#    np.float64(0.5323926296278343),
#    np.float64(0.2749313551529547)],
#   [np.float64(0.37305845303875634),
#    np.float64(4.845028456676796),
#    np.float64(4.845028456676796),
#    np.float64(0.5323926296278343)]],
#  'ivl': ['2', '0', '1', '3', '4', '5'],
#  'leaves': [2, 0, 1, 3, 4, 5],
#  'color_list': ['C1', 'C1', 'C2', 'C2', 'C0'],
#  'leaves_color_list': ['C1', 'C1', 'C1', 'C2', 'C2', 'C2']}

# %%
plt.xlabel("Data Points")
plt.ylabel("Distance")
plt.title("Dendogram")
plt.show()
