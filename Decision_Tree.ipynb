# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
data = {
    "Age": [22, 25, 28, 30, 35, 40, 45, 50, 23, 27],
    "Salary": [25000, 30000, 35000, 45000, 60000, 70000, 80000, 90000, 28000, 40000],
    "Purchased": [0, 0, 0, 1, 1, 1, 1, 1, 0, 1]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Age  Salary  Purchased
# 0   22   25000          0
# 1   25   30000          0
# 2   28   35000          0
# 3   30   45000          1
# 4   35   60000          1
# 5   40   70000          1
# 6   45   80000          1
# 7   50   90000          1
# 8   23   28000          0
# 9   27   40000          1

# %%
df.head()
# Out:
#    Age  Salary  Purchased
# 0   22   25000          0
# 1   25   30000          0
# 2   28   35000          0
# 3   30   45000          1
# 4   35   60000          1

# %%
df.isnull().sum()
# Out:
# Age          0
# Salary       0
# Purchased    0
# dtype: int64

# %%
#independent and dependent feature
x=df[["Age","Salary"]]
y=df["Purchased"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#decision tree model
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier(
    criterion='gini',
    max_depth=5,
    random_state=42
)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
y_pred=model.predict(x_test)
print("Predicted:",y_pred)
print("Actual:",y_test.values)
# Out:
# Predicted: [0 0]
# Actual: [0 0]

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
print("Accuracy:\n",accuracy_score(y_test,y_pred))
print("Confusion_Matrix:\n",confusion_matrix(y_test,y_pred))
print("Classification_report:\n",classification_report(y_test,y_pred))
# Out:
# Accuracy:
#  1.0
# Confusion_Matrix:
#  [[2]]
# Classification_report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2
# c:\Users\ADITYA RAO\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:407: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %%
#visualize tree
from sklearn.tree import plot_tree
plt.figure(figsize=(5,6))

plot_tree(
    model,
    feature_names=['Age','Salary'],
    class_names=['No','Yes'],
    filled=True
)
plt.show()

# %%
#new prediction
# age = 32 , salary = 55000
new_customer=[[32,55000]]
prediction=model.predict(new_customer)
print("Preiction:",prediction)
if(prediction==1):
    print("Purchased")
else:
    print("Not Purchased")
# Out:
# Preiction: [1]
# Purchased
# c:\Users\ADITYA RAO\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
